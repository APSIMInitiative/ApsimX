# %%
import pandas as pd

# %%
dtypes = {'$type': 'str',
 'HarvestIndex': 'float',
 'MoistureContent': 'float',
 'RootProportion': 'float',
 'MaxRootDepth': 'float',
 'MaxHeight': 'float',
 'MaxCover': 'float',
 'ExtinctionCoefficient': 'float',
 'TypicalHarvestStage': 'str',
 'SeedlingNConc': 'float',
 'ProductHarvestNConc': 'float',
 'StoverHarvestNConc': 'float',
 'RootNConc': 'float',
 'LegumeFactor': 'float',
 'BaseTemperature': 'float',
 'OptimumTemperature': 'float',
 'MaxTemperature': 'float',
 'Tt_SowToEmergence': 'float',
 'GSMax': 'float',
 'R50': 'float',
 'ConsiderWaterStress': 'str',
 'Name': 'str'}

# %%
data = pd.read_excel('ExampleScrumCropInstances.xlsx',sheet_name='SCRUM Example Crops',
                    skiprows=[0,1],usecols='I:AD',dtype=dtypes)

# %%
data
# Out:
#                                                 $type  HarvestIndex  \
# 0   Models.PMF.SimplePlantModels.ScrumCropInstance...        0.8895
# 1   Models.PMF.SimplePlantModels.ScrumCropInstance...        0.8340
# 2   Models.PMF.SimplePlantModels.ScrumCropInstance...        0.7780
# 3   Models.PMF.SimplePlantModels.ScrumCropInstance...        0.5800
# 4   Models.PMF.SimplePlantModels.ScrumCropInstance...        0.8720
# ..                                                ...           ...
# 80                                                NaN           NaN
# 81                                                NaN           NaN
# 82                                                NaN           NaN
# 83                                                NaN           NaN
# 84                                                NaN           NaN
#
#     MoistureContent  RootProportion  MaxRootDepth  MaxHeight  MaxCover  \
# 0               0.0             0.1   1500.000000      500.0       1.0
# ...

# %%
crops = []
for c in data.index:
    crops.append(data.iloc[c,:].to_dict())

# %%
crops
# Out:
# [{'$type': 'Models.PMF.SimplePlantModels.ScrumCropInstance, Models',
#   'HarvestIndex': 0.8895000219345093,
#   'MoistureContent': 0.0,
#   'RootProportion': 0.10000000149011612,
#   'MaxRootDepth': 1500.0,
#   'MaxHeight': 500.0,
#   'MaxCover': 1.0,
#   'ExtinctionCoefficient': 0.5,
#   'TypicalHarvestStage': 'EarlyReproductive',
#   'SeedlingNConc': 0.05,
#   'ProductHarvestNConc': 0.01,
#   'StoverHarvestNConc': 0.015,
#   'RootNConc': 0.00800000011920929,
#   'LegumeFactor': 0.0,
#   'BaseTemperature': 1.0,
#   'OptimumTemperature': 25.0,
#   'MaxTemperature': 35.0,
#   'Tt_SowToEmergence': 100.0,
#   'GSMax': 0.008,
#   'R50': 150.0,
#   'ConsiderWaterStress': 'true',
#   'Name': 'Fodder beet Fodder'},
#  {'$type': 'Models.PMF.SimplePlantModels.ScrumCropInstance, Models',
#   'HarvestIndex': 0.8339999914169312,
#   'MoistureContent': 0.0,
#   'RootProportion': 0.10000000149011612,
#   'MaxRootDepth': 1200.0000476837158,
#   'MaxHeight': 500.0,
#   'MaxCover': 1.0,
# ...
